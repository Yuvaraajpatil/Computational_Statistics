# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA #ML lib PCA is in this library
from sklearn.preprocessing import StandardScaler # standarsding data
import matplotlib.pyplot as plt # plotting visulization

# %%
df=pd.read_csv("/content/International wheat production statistics.csv")

# %%
df
# Out:
#     Unnamed: 0         Country  2020[1]  2019[1]  2018[1]  2017[1]  2016[1]  \
# 0            0           China    134.3    133.6    131.4    134.3    131.7
# 1            1           India    107.6    103.6     99.7     98.5     93.5
# 2            2          Russia     85.9     74.5     72.1     85.9     73.3
# 3            3   United States     49.7     52.3     51.3     47.3     62.9
# 4            4          Canada     35.2     32.3     31.8     30.0     30.5
# 5            5          France     30.1     40.6     35.8     36.9     29.5
# 6            6        Pakistan     25.2     24.4     25.1     26.7     26.0
# 7            7         Ukraine     24.9     28.4     24.7     26.2     26.1
# 8            8         Germany     22.2     23.1     20.3     24.5     24.5
# 9            9          Turkey     20.5     19.0     20.0     21.5     20.6
# 10          10       Argentina     19.8     19.5     18.5     18.4     18.6
# ...

# %%
features = ['Country','2020[1]','2019[1]','2018[1]','2017[1]','2016[1]','2015[2]','2014[3]','2013[4]','2012[5]','2011[5]','2010[5]','2009[5]','2008[5]','2007[5]','2006[5]','2005 [6]','2004[6]','2003[6]','2002','2001','2000','1999','1998','1997','1996']
 # x values
x = df.drop(columns='Country',axis=1)
y = df["Country"]

# %%
x
# Out:
#     Unnamed: 0  2020[1]  2019[1]  2018[1]  2017[1]  2016[1]  2015[2]  2014[3]  \
# 0            0    134.3    133.6    131.4    134.3    131.7    130.2    126.2
# 1            1    107.6    103.6     99.7     98.5     93.5     86.5     94.5
# 2            2     85.9     74.5     72.1     85.9     73.3     61.8     59.7
# 3            3     49.7     52.3     51.3     47.3     62.9     55.8     55.4
# 4            4     35.2     32.3     31.8     30.0     30.5     27.6     29.3
# 5            5     30.1     40.6     35.8     36.9     29.5     42.8     39.0
# 6            6     25.2     24.4     25.1     26.7     26.0     25.1     26.0
# 7            7     24.9     28.4     24.7     26.2     26.1     26.5     24.1
# 8            8     22.2     23.1     20.3     24.5     24.5     26.5     27.8
# 9            9     20.5     19.0     20.0     21.5     20.6     22.6     19.0
# 10          10     19.8     19.5     18.5     18.4     18.6     11.6     13.9
# ...

# %%
x = StandardScaler(). fit_transform(x)
x
# Out:
# array([[-1.69129096e+00,  8.46150640e-01,  8.34766520e-01, ...,
#          8.99300647e-01,  1.00320498e+00,  9.42265178e-01],
#        [-1.60878896e+00,  6.17236180e-01,  5.78728103e-01, ...,
#          4.19764003e-01,  4.32401595e-01,  4.00835336e-01],
#        [-1.52628697e+00,  4.31189596e-01,  3.30370839e-01, ...,
#         -6.12584864e-03,  1.66591483e-01,  8.83851988e-02],
#        ...,
#        [ 1.52628697e+00, -2.87276012e-01, -2.89242129e-01, ...,
#         -2.82023644e-01, -2.82426396e-01, -2.86103775e-01],
#        [ 1.60878896e+00, -2.87276012e-01, -2.92655974e-01, ...,
#         -2.80928812e-01, -2.77131374e-01, -2.74823986e-01],
#        [ 1.69129096e+00,  6.21835291e+00,  6.23034942e+00, ...,
#          6.22566087e+00,  6.20715276e+00,  6.22120613e+00]])

# %%
x = StandardScaler(). fit_transform(x)
df2 = pd.DataFrame(data = x, columns=features)
df2.head()
# Out:
#     Country   2020[1]   2019[1]   2018[1]   2017[1]   2016[1]   2015[2]  \
# 0 -1.691291  0.846151  0.834767  0.863404  0.831495  0.843487  0.851220
# 1 -1.608789  0.617236  0.578728  0.581378  0.528283  0.510279  0.462948
# 2 -1.526287  0.431190  0.330371  0.335829  0.421565  0.334080  0.243490
# 3 -1.443785  0.120826  0.140902  0.150778  0.094638  0.243364  0.190180
# 4 -1.361283 -0.003491 -0.029790 -0.022708 -0.051887 -0.039252 -0.060375
#
#     2014[3]   2013[4]   2012[5]  ...  2005 [6]   2004[6]   2003[6]      2002  \
# 0  0.820691  0.813946  0.911807  ...  0.702492  0.644305  0.722688  0.700118
# 1  0.537748  0.554406  0.614181  ...  0.447988  0.442413  0.467772  0.506234
# 2  0.227136  0.173378  0.059645  ...  0.192437  0.165976  0.098501  0.260279
# 3  0.188756  0.246086  0.293287  ...  0.291934  0.303677  0.452286  0.188265
# 4 -0.044203  0.039006 -0.044088  ... -0.037979 -0.035917 -0.026575 -0.120841
#
#        2001      2000      1999      1998      1997      1996
# ...

# %%
df.corr()
# Out:
#             Unnamed: 0   2020[1]   2019[1]   2018[1]   2017[1]   2016[1]  \
# Unnamed: 0    1.000000  0.098088  0.100633  0.098548  0.100567  0.100859
# 2020[1]       0.098088  1.000000  0.999657  0.999688  0.999496  0.999429
# 2019[1]       0.100633  0.999657  1.000000  0.999903  0.999605  0.999629
# 2018[1]       0.098548  0.999688  0.999903  1.000000  0.999697  0.999712
# 2017[1]       0.100567  0.999496  0.999605  0.999697  1.000000  0.999496
# 2016[1]       0.100859  0.999429  0.999629  0.999712  0.999496  1.000000
# 2015[2]       0.106200  0.998733  0.999503  0.999501  0.999286  0.999560
# 2014[3]       0.104007  0.998981  0.999653  0.999638  0.999338  0.999641
# 2013[4]       0.102440  0.998549  0.999257  0.999311  0.998692  0.999318
# 2012[5]       0.098589  0.997221  0.998295  0.998437  0.997592  0.998417
# 2011[5]       0.103959  0.998632  0.999334  0.999431  0.999193  0.999498
# 2010[5]       0.100873  0.997723  0.998808  0.998823  0.998122  0.999016
# ...

# %%
pca = PCA()
sy = pca.fit_transform(x)

# %%
sy
# Out:
# array([[ 4.09798202e+00,  1.78554081e+00, -9.97160773e-02, ...,
#          2.59500587e-04, -4.21511534e-04, -2.78785846e-04],
#        [ 2.46342667e+00,  1.66350712e+00,  1.64152822e-01, ...,
#          8.22658314e-04,  2.18950502e-05, -4.47387920e-04],
#        [ 1.00703545e+00,  1.54789276e+00,  5.38310363e-01, ...,
#          1.41376650e-04,  7.76567216e-06,  9.52081438e-05],
#        ...,
#        [-1.40910084e+00, -1.55644392e+00, -7.13785373e-04, ...,
#          1.44176582e-03,  3.75301944e-04,  4.94364327e-04],
#        [-1.39193721e+00, -1.63855438e+00, -1.40905855e-02, ...,
#          2.02882754e-03,  2.19034352e-03, -7.63064146e-05],
#        [ 3.12061372e+01, -1.02713939e+00,  9.42743814e-03, ...,
#         -1.23722784e-04,  2.01303416e-05,  3.21172103e-05]])

# %%
pca = PCA(n_components=4)
principalComponents = pca.fit_transform(x)

# %%
principleDf = pd.DataFrame(data=principalComponents, columns= ['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4'])

# %%
principleDf.head(10)
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               4.097982               1.785541              -0.099716
# 1               2.463427               1.663507               0.164153
# 2               1.007035               1.547893               0.538310
# 3               1.356890               1.473695              -0.470595
# 4              -0.214422               1.358025              -0.036656
# 5               0.281367               1.283356              -0.163191
# 6              -0.455955               1.186439               0.019633
# 7              -0.594298               1.100584               0.149975
# 8              -0.412648               1.021265              -0.035866
# 9              -0.574274               0.935237              -0.032192
#
#    principal component 4
# 0               0.364408
# 1               0.069726
# 2              -0.038382
# 3              -0.051552
# 4               0.029485
# 5              -0.085100
# ...

# %%
plt.subplot(121)
plt.scatter(x[:,0], x[:,1])
plt.xlabel('x1')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %%
df.hist(figsize=(15,12),bins=15)
plt.title("Features Distribution")
plt.show()

# %%
pip install factor_analyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import required libraries
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/International wheat production statistics.csv")
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', '2020[1]', '2019[1]', '2018[1]', '2017[1]',
#        '2016[1]', '2015[2]', '2014[3]', '2013[4]', '2012[5]', '2011[5]',
#        '2010[5]', '2009[5]', '2008[5]', '2007[5]', '2006[5]', '2005 [6]',
#        '2004[6]', '2003[6]', '2002', '2001', '2000', '1999', '1998', '1997',
#        '1996'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0        Country  2020[1]  2019[1]  2018[1]  2017[1]  2016[1]  \
# 0           0          China    134.3    133.6    131.4    134.3    131.7
# 1           1          India    107.6    103.6     99.7     98.5     93.5
# 2           2         Russia     85.9     74.5     72.1     85.9     73.3
# 3           3  United States     49.7     52.3     51.3     47.3     62.9
# 4           4         Canada     35.2     32.3     31.8     30.0     30.5
#
#    2015[2]  2014[3]  2013[4]  ...  2005 [6]  2004[6]  2003[6]  2002  2001  \
# 0    130.2    126.2    121.7  ...      96.3     91.6     86.5  90.3  93.9
# 1     86.5     94.5     93.5  ...      72.0     72.1     65.1  72.8  69.7
# 2     61.8     59.7     52.1  ...      47.6     45.4     34.1  50.6  47.0
# 3     55.8     55.4     60.0  ...      57.1     58.7     63.8  44.1  53.3
# 4     27.6     29.3     37.5  ...      25.6     25.9     23.6  16.2  20.6
#
#    2000   1999   1998   1997   1996
# 0  99.7  113.9  109.7  123.3  110.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  42 non-null     int64
#  1   Country     42 non-null     object
#  2   2020[1]     42 non-null     float64
#  3   2019[1]     42 non-null     float64
#  4   2018[1]     42 non-null     float64
#  5   2017[1]     42 non-null     float64
#  6   2016[1]     42 non-null     float64
#  7   2015[2]     42 non-null     float64
#  8   2014[3]     42 non-null     float64
#  9   2013[4]     42 non-null     float64
#  10  2012[5]     42 non-null     float64
#  11  2011[5]     42 non-null     float64
#  12  2010[5]     42 non-null     float64
#  13  2009[5]     42 non-null     float64
#  14  2008[5]     42 non-null     float64
#  15  2007[5]     42 non-null     float64
#  16  2006[5]     42 non-null     float64
#  17  2005 [6]    42 non-null     float64
# ...

# %%
df.drop(['Country','2020[1]','2019[1]','2018[1]','2017[1]','2016[1]','2015[2]','2014[3]'],axis= 1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  2013[4]  2012[5]  2011[5]  2010[5]  2009[5]  2008[5]  2007[5]  \
# 0           0    121.7    125.6    117.4    115.2    115.1    112.5    109.9
# 1           1     93.5     94.9     86.9     80.7     80.7     78.6     74.9
# 2           2     52.1     37.7     56.2     41.5     61.7     63.7     49.4
# 3           3     60.0     61.8     54.4     60.1     60.3     68.0     53.6
# 4           4     37.5     27.0     25.3     23.2     26.8     28.6     20.6
#
#    2006[5]  2005 [6]  2004[6]  2003[6]  2002  2001  2000   1999   1998   1997  \
# 0    104.5      96.3     91.6     86.5  90.3  93.9  99.7  113.9  109.7  123.3
# 1     69.4      72.0     72.1     65.1  72.8  69.7  76.4   70.8   65.9   69.4
# 2     45.0      47.6     45.4     34.1  50.6  47.0  34.5   31.0   27.0   44.3
# 3     57.3      57.1     58.7     63.8  44.1  53.3  60.8   62.7   69.4   67.5
# 4     27.3      25.6     25.9     23.6  16.2  20.6  26.8   26.9   24.1   24.3
#
#     1996
# 0  110.6
# 1   62.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  42 non-null     int64
#  1   2013[4]     42 non-null     float64
#  2   2012[5]     42 non-null     float64
#  3   2011[5]     42 non-null     float64
#  4   2010[5]     42 non-null     float64
#  5   2009[5]     42 non-null     float64
#  6   2008[5]     42 non-null     float64
#  7   2007[5]     42 non-null     float64
#  8   2006[5]     42 non-null     float64
#  9   2005 [6]    42 non-null     float64
#  10  2004[6]     42 non-null     float64
#  11  2003[6]     42 non-null     float64
#  12  2002        42 non-null     float64
#  13  2001        42 non-null     float64
#  14  2000        42 non-null     float64
#  15  1999        42 non-null     float64
#  16  1998        42 non-null     float64
#  17  1997        42 non-null     float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  2013[4]  2012[5]  2011[5]  2010[5]  2009[5]  2008[5]  2007[5]  \
# 0           0    121.7    125.6    117.4    115.2    115.1    112.5    109.9
# 1           1     93.5     94.9     86.9     80.7     80.7     78.6     74.9
# 2           2     52.1     37.7     56.2     41.5     61.7     63.7     49.4
# 3           3     60.0     61.8     54.4     60.1     60.3     68.0     53.6
# 4           4     37.5     27.0     25.3     23.2     26.8     28.6     20.6
#
#    2006[5]  2005 [6]  2004[6]  2003[6]  2002  2001  2000   1999   1998   1997  \
# 0    104.5      96.3     91.6     86.5  90.3  93.9  99.7  113.9  109.7  123.3
# 1     69.4      72.0     72.1     65.1  72.8  69.7  76.4   70.8   65.9   69.4
# 2     45.0      47.6     45.4     34.1  50.6  47.0  34.5   31.0   27.0   44.3
# 3     57.3      57.1     58.7     63.8  44.1  53.3  60.8   62.7   69.4   67.5
# 4     27.3      25.6     25.9     23.6  16.2  20.6  26.8   26.9   24.1   24.3
#
#     1996
# 0  110.6
# 1   62.6
# ...

# %%
df.corr()
# Out:
#             Unnamed: 0   2013[4]   2012[5]   2011[5]   2010[5]   2009[5]  \
# Unnamed: 0    1.000000  0.102440  0.098589  0.103959  0.100873  0.103539
# 2013[4]       0.102440  1.000000  0.999399  0.999567  0.999555  0.999600
# 2012[5]       0.098589  0.999399  1.000000  0.999084  0.999683  0.998802
# 2011[5]       0.103959  0.999567  0.999084  1.000000  0.999447  0.999731
# 2010[5]       0.100873  0.999555  0.999683  0.999447  1.000000  0.999403
# 2009[5]       0.103539  0.999600  0.998802  0.999731  0.999403  1.000000
# 2008[5]       0.100133  0.999307  0.998358  0.999289  0.999111  0.999759
# 2007[5]       0.099608  0.999323  0.999046  0.999553  0.999600  0.999584
# 2006[5]       0.106774  0.999457  0.998864  0.999366  0.999583  0.999585
# 2005 [6]      0.106418  0.999375  0.998782  0.999552  0.999455  0.999586
# 2004[6]       0.111726  0.999151  0.998402  0.999212  0.999191  0.999309
# 2003[6]       0.104597  0.998637  0.998760  0.998603  0.999162  0.998663
# ...

# %%
df.count()
# Out:
# Unnamed: 0    42
# 2013[4]       42
# 2012[5]       42
# 2011[5]       42
# 2010[5]       42
# 2009[5]       42
# 2008[5]       42
# 2007[5]       42
# 2006[5]       42
# 2005 [6]      42
# 2004[6]       42
# 2003[6]       42
# 2002          42
# 2001          42
# 2000          42
# 1999          42
# 1998          42
# 1997          42
# 1996          42
# dtype: int64
